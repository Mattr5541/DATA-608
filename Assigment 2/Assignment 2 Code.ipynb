# %%
##Importing Libraries

import requests
import json
import prettytable
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import fredapi as Fred
import datetime as dt
import matplotlib.dates as mdates

# %%
##Pulling CPI Data

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0'],"startyear":"1999", "endyear":"2024", "registrationkey": "4a829b23e1c040e2b9e09ce767d70e49"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()


for i in json_data:
    id = series['seriesID']
    with open("CPI" + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["series id", "year", "period", "value"])
        
        for item in series['data']:
            year = item['year']
            period = item['period']
            value = item['value'] 
            writer.writerow([id, year, period, value]) 

CPI_99to18 = pd.read_csv("CPI.csv")
CPI_99to18

CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M01"), 'January', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M02"), 'February', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M03"), 'March', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M04"), 'April', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M05"), 'May', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M06"), 'June', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M07"), 'July', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M08"), 'August', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M09"), 'September', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M10"), 'October', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M11"), 'November', CPI_99to18['period'])
CPI_99to18["period"] = np.where(CPI_99to18['period'].str.contains("M12"), 'December', CPI_99to18['period'])

CPI_99to18
# Out:
#        series id  year     period    value
# 0    CUUR0000SA0  2018   December  251.233
# 1    CUUR0000SA0  2018   November  252.038
# 2    CUUR0000SA0  2018    October  252.885
# 3    CUUR0000SA0  2018  September  252.439
# 4    CUUR0000SA0  2018     August  252.146
# ..           ...   ...        ...      ...
# 235  CUUR0000SA0  1999        May  166.200
# 236  CUUR0000SA0  1999      April  166.200
# 237  CUUR0000SA0  1999      March  165.000
# 238  CUUR0000SA0  1999   February  164.500
# 239  CUUR0000SA0  1999    January  164.300
#
# [240 rows x 4 columns]

# %%
##Pulling CPI Data

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0'],"startyear":"2019", "endyear":"2024", "registrationkey": "4a829b23e1c040e2b9e09ce767d70e49"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()


for i in json_data:
    id = series['seriesID']
    with open("CPI" + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["series id", "year", "period", "value"])
        
        for item in series['data']:
            year = item['year']
            period = item['period']
            value = item['value'] 
            writer.writerow([id, year, period, value]) 

CPI_19to24 = pd.read_csv("CPI.csv")
CPI_19to24

CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M01"), 'January', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M02"), 'February', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M03"), 'March', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M04"), 'April', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M05"), 'May', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M06"), 'June', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M07"), 'July', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M08"), 'August', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M09"), 'September', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M10"), 'October', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M11"), 'November', CPI_19to24['period'])
CPI_19to24["period"] = np.where(CPI_19to24['period'].str.contains("M12"), 'December', CPI_19to24['period'])

CPI_19to24
# Out:
#       series id  year    period    value
# 0   CUUR0000SA0  2024    August  314.796
# 1   CUUR0000SA0  2024      July  314.540
# 2   CUUR0000SA0  2024      June  314.175
# 3   CUUR0000SA0  2024       May  314.069
# 4   CUUR0000SA0  2024     April  313.548
# ..          ...   ...       ...      ...
# 63  CUUR0000SA0  2019       May  256.092
# 64  CUUR0000SA0  2019     April  255.548
# 65  CUUR0000SA0  2019     March  254.202
# 66  CUUR0000SA0  2019  February  252.776
# 67  CUUR0000SA0  2019   January  251.712
#
# [68 rows x 4 columns]

# %%
## Append Data

#CPI_99to08 = pd.DataFrame(CPI_99to08)
#CPI_09to18 = pd.DataFrame(CPI_09to18)
#CPI_19to24 = pd.DataFrame(CPI_19to24)

CPI = pd.concat([CPI_99to18, CPI_19to24], ignore_index= True)

CPI
# Out:
#        series id  year     period    value
# 0    CUUR0000SA0  2018   December  251.233
# 1    CUUR0000SA0  2018   November  252.038
# 2    CUUR0000SA0  2018    October  252.885
# 3    CUUR0000SA0  2018  September  252.439
# 4    CUUR0000SA0  2018     August  252.146
# ..           ...   ...        ...      ...
# 303  CUUR0000SA0  2019        May  256.092
# 304  CUUR0000SA0  2019      April  255.548
# 305  CUUR0000SA0  2019      March  254.202
# 306  CUUR0000SA0  2019   February  252.776
# 307  CUUR0000SA0  2019    January  251.712
#
# [308 rows x 4 columns]

# %%
##Pull Unemployment Data

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['LNS14000000'],"startyear":"1999", "endyear":"2024", "registrationkey": "4a829b23e1c040e2b9e09ce767d70e49"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()


for i in json_data:
    id = series['seriesID']
    with open("Unemployment" + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["series id", "year", "period", "value"])
        
        for item in series['data']:
            year = item['year']
            period = item['period']
            value = item['value'] 
            writer.writerow([id, year, period, value]) 

Unemploy_99to18 = pd.read_csv("Unemployment.csv")

Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M01"), 'January', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M02"), 'February', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M03"), 'March', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M04"), 'April', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M05"), 'May', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M06"), 'June', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M07"), 'July', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M08"), 'August', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M09"), 'September', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M10"), 'October', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M11"), 'November', Unemploy_99to18['period'])
Unemploy_99to18["period"] = np.where(Unemploy_99to18['period'].str.contains("M12"), 'December', Unemploy_99to18['period'])

Unemploy_99to18
# Out:
#        series id  year     period  value
# 0    LNS14000000  2018   December    3.9
# 1    LNS14000000  2018   November    3.8
# 2    LNS14000000  2018    October    3.8
# 3    LNS14000000  2018  September    3.7
# 4    LNS14000000  2018     August    3.8
# ..           ...   ...        ...    ...
# 235  LNS14000000  1999        May    4.2
# 236  LNS14000000  1999      April    4.3
# 237  LNS14000000  1999      March    4.2
# 238  LNS14000000  1999   February    4.4
# 239  LNS14000000  1999    January    4.3
#
# [240 rows x 4 columns]

# %%
##Pull Unemployment Data

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['LNS14000000'],"startyear":"2019", "endyear":"2024", "registrationkey": "4a829b23e1c040e2b9e09ce767d70e49"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()


for i in json_data:
    id = series['seriesID']
    with open("Unemployment" + '.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["series id", "year", "period", "value"])
        
        for item in series['data']:
            year = item['year']
            period = item['period']
            value = item['value'] 
            writer.writerow([id, year, period, value]) 

Unemploy_19to24 = pd.read_csv("Unemployment.csv")

Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M01"), 'January', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M02"), 'February', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M03"), 'March', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M04"), 'April', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M05"), 'May', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M06"), 'June', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M07"), 'July', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M08"), 'August', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M09"), 'September', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M10"), 'October', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M11"), 'November', Unemploy_19to24['period'])
Unemploy_19to24["period"] = np.where(Unemploy_19to24['period'].str.contains("M12"), 'December', Unemploy_19to24['period'])

Unemploy_19to24
# Out:
#       series id  year    period  value
# 0   LNS14000000  2024    August    4.2
# 1   LNS14000000  2024      July    4.3
# 2   LNS14000000  2024      June    4.1
# 3   LNS14000000  2024       May    4.0
# 4   LNS14000000  2024     April    3.9
# ..          ...   ...       ...    ...
# 63  LNS14000000  2019       May    3.6
# 64  LNS14000000  2019     April    3.7
# 65  LNS14000000  2019     March    3.8
# 66  LNS14000000  2019  February    3.8
# 67  LNS14000000  2019   January    4.0
#
# [68 rows x 4 columns]

# %%
##Append Unemployment Data

Unemployment = pd.concat([Unemploy_99to18, Unemploy_19to24], ignore_index= True)

Unemployment
# Out:
#        series id  year     period  value
# 0    LNS14000000  2018   December    3.9
# 1    LNS14000000  2018   November    3.8
# 2    LNS14000000  2018    October    3.8
# 3    LNS14000000  2018  September    3.7
# 4    LNS14000000  2018     August    3.8
# ..           ...   ...        ...    ...
# 303  LNS14000000  2019        May    3.6
# 304  LNS14000000  2019      April    3.7
# 305  LNS14000000  2019      March    3.8
# 306  LNS14000000  2019   February    3.8
# 307  LNS14000000  2019    January    4.0
#
# [308 rows x 4 columns]

# %%
'''Sources for code:
https://www.youtube.com/watch?v=M_jswxN3iwI
https://fred.stlouisfed.org/
'''

'''string, optional, default: lin (No transformation)
One of the following values: 'lin', 'chg', 'ch1', 'pch', 'pc1', 'pca', 'cch', 'cca', 'log'
lin = Levels (No transformation)
chg = Change
ch1 = Change from Year Ago
pch = Percent Change
pc1 = Percent Change from Year Ago
pca = Compounded Annual Rate of Change
cch = Continuously Compounded Rate of Change
cca = Continuously Compounded Annual Rate of Change
log = Natural Log'''

##Pull FED Data

api_key = "f86f217181e7b1a537ac00816a67bb02" 
base_url = 'https://api.stlouisfed.org/fred/'
endpoint = 'series/observations'

series_id = 'DFF'
start_date = '1999-01-01'
end_date = '2024-08-31'
ts_frequency = 'm'
ts_units = 'lin'
#agg_method = 'sum'

obs_params = {
    'series_id': series_id,
    'api_key': api_key,
    'file_type': 'json',
    'observation_start': start_date,
    'observation_end': end_date,
    'frequency': ts_frequency,
    'units': ts_units
}

response = requests.get(base_url + endpoint, params = obs_params)

if response.status_code == 200:
    res_data = response.json()
    obs_data = pd.DataFrame(res_data['observations'])
    obs_data['date'] = pd.to_datetime(obs_data['date'])
    obs_data.set_index('date', inplace = True)
    obs_data['value'] = obs_data['value'].astype(float)
else:
    print('Failure', response.status_code)

# %%
print(obs_data)

##Clean FED Data

fed = obs_data.drop(columns = ['realtime_start', 'realtime_end'])

fed = fed.reset_index()

#fed = fed.rename(columns = {"date": "year"})

print(fed)

fed['period'] = None
fed['period'] = np.where(fed['date'].dt.month == 1, 'January', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 2, 'February', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 3, 'March', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 4, 'April', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 5, 'May', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 6, 'June', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 7, 'July', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 8, 'August', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 9, 'September', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 10, 'October', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 11, 'November', fed['period'])
fed['period'] = np.where(fed['date'].dt.month == 12, 'December', fed['period'])

fed['year'] = fed['date'].dt.year


print(fed)
# Out:
#            realtime_start realtime_end  value
# date
# 1999-01-01     2024-09-29   2024-09-29   4.63
# 1999-02-01     2024-09-29   2024-09-29   4.76
# 1999-03-01     2024-09-29   2024-09-29   4.81
# 1999-04-01     2024-09-29   2024-09-29   4.74
# 1999-05-01     2024-09-29   2024-09-29   4.74
# ...                   ...          ...    ...
# 2024-04-01     2024-09-29   2024-09-29   5.33
# 2024-05-01     2024-09-29   2024-09-29   5.33
# 2024-06-01     2024-09-29   2024-09-29   5.33
# 2024-07-01     2024-09-29   2024-09-29   5.33
# 2024-08-01     2024-09-29   2024-09-29   5.33
#
# [308 rows x 3 columns]
#           date  value
# 0   1999-01-01   4.63
# 1   1999-02-01   4.76
# 2   1999-03-01   4.81
# 3   1999-04-01   4.74
# 4   1999-05-01   4.74
# ..         ...    ...
# 303 2024-04-01   5.33
# 304 2024-05-01   5.33
# 305 2024-06-01   5.33
# 306 2024-07-01   5.33
# 307 2024-08-01   5.33
#
# [308 rows x 2 columns]
#           date  value    period  year
# ...

# %%
#Renaming Values
CPI = CPI.rename(columns = {'value': 'CPI'})

CPI = CPI.drop(columns = ["series id"])

print(CPI)

Unemployment = Unemployment.rename(columns = {'value':'Unemployment'})

Unemployment = Unemployment.drop(columns = ["series id"])

print(Unemployment)

fed = fed.rename(columns = {'value': 'Fed_Percent'})

print(fed)
# Out:
#      year     period      CPI
# 0    2018   December  251.233
# 1    2018   November  252.038
# 2    2018    October  252.885
# 3    2018  September  252.439
# 4    2018     August  252.146
# ..    ...        ...      ...
# 303  2019        May  256.092
# 304  2019      April  255.548
# 305  2019      March  254.202
# 306  2019   February  252.776
# 307  2019    January  251.712
#
# [308 rows x 3 columns]
#      year     period  Unemployment
# 0    2018   December           3.9
# 1    2018   November           3.8
# 2    2018    October           3.8
# 3    2018  September           3.7
# 4    2018     August           3.8
# ..    ...        ...           ...
# 303  2019        May           3.6
# 304  2019      April           3.7
# 305  2019      March           3.8
# 306  2019   February           3.8
# 307  2019    January           4.0
#
# [308 rows x 3 columns]
#           date  Fed_Percent    period  year
# 0   1999-01-01         4.63   January  1999
# ...

# %%
#Merging Datasets

merged_data = pd.merge(CPI, Unemployment, on = ['year', 'period'])

merged_data = pd.merge(merged_data, fed, on = ['year', 'period'])

print(merged_data)
# Out:
#      year     period      CPI  Unemployment       date  Fed_Percent
# 0    2018   December  251.233           3.9 2018-12-01         2.27
# 1    2018   November  252.038           3.8 2018-11-01         2.20
# 2    2018    October  252.885           3.8 2018-10-01         2.19
# 3    2018  September  252.439           3.7 2018-09-01         1.95
# 4    2018     August  252.146           3.8 2018-08-01         1.91
# ..    ...        ...      ...           ...        ...          ...
# 303  2019        May  256.092           3.6 2019-05-01         2.39
# 304  2019      April  255.548           3.7 2019-04-01         2.42
# 305  2019      March  254.202           3.8 2019-03-01         2.41
# 306  2019   February  252.776           3.8 2019-02-01         2.40
# 307  2019    January  251.712           4.0 2019-01-01         2.40
#
# [308 rows x 6 columns]

# %%
merged_data.to_csv('merged_data.csv', index = False)

# %%
#merged_data['datetime'] = pd.to_datetime(merged_data['year'].astype(str) + ' ' + merged_data['period'].astype(str))


#merged_data = merged_data.sort_values(by= 'datetime')

print(merged_data)
# Out:
#      year     period      CPI  Unemployment       date  Fed_Percent
# 0    2018   December  251.233           3.9 2018-12-01         2.27
# 1    2018   November  252.038           3.8 2018-11-01         2.20
# 2    2018    October  252.885           3.8 2018-10-01         2.19
# 3    2018  September  252.439           3.7 2018-09-01         1.95
# 4    2018     August  252.146           3.8 2018-08-01         1.91
# ..    ...        ...      ...           ...        ...          ...
# 303  2019        May  256.092           3.6 2019-05-01         2.39
# 304  2019      April  255.548           3.7 2019-04-01         2.42
# 305  2019      March  254.202           3.8 2019-03-01         2.41
# 306  2019   February  252.776           3.8 2019-02-01         2.40
# 307  2019    January  251.712           4.0 2019-01-01         2.40
#
# [308 rows x 6 columns]

# %%
merged_data['date'] = pd.to_datetime(merged_data['date'])

# %%
CPI_data = merged_data[['year', 'period', 'date', 'CPI']]

CPI_data = CPI_data.sort_values(by=['date'])

CPI_data['CPI_lag_year'] = CPI_data.groupby(['period'])['CPI'].shift(1)

CPI_data['CPI_Percent'] = ((CPI_data['CPI'] - CPI_data['CPI_lag_year']) / CPI_data['CPI_lag_year']) * 100

CPI_data.drop(columns=['CPI_lag_year'], inplace=True)

twelve = [1.7, 1.6, 1.7, 2.3, 2.1, 2.0, 2.1,2.3,2.6, 2.6, 2.6, 2.7]

#CPI_data.loc[:11, 'CPI_Percent_Annual'] = twelve

map = {
    pd.to_datetime('1999-01-01 00:00:00') : 1.7,
    pd.to_datetime('1999-02-01 00:00:00') : 1.6,
    pd.to_datetime('1999-03-01 00:00:00') : 1.7,
    pd.to_datetime('1999-04-01 00:00:00') : 2.3,
    pd.to_datetime('1999-05-01 00:00:00') : 2.1,
    pd.to_datetime('1999-06-01 00:00:00') : 2.0,
    pd.to_datetime('1999-07-01 00:00:00') : 2.1,
    pd.to_datetime('1999-08-01 00:00:00') : 2.3,
    pd.to_datetime('1999-09-01 00:00:00') : 2.6,
    pd.to_datetime('1999-10-01 00:00:00') : 2.6,
    pd.to_datetime('1999-11-01 00:00:00') : 2.6,
    pd.to_datetime('1999-12-01 00:00:00') : 2.7
}

CPI_data['CPI_Percent'] = CPI_data['CPI_Percent'].fillna(CPI_data['date'].map(map))

CPI_data['CPI_Percent'] = round(CPI_data['CPI_Percent'], 2)

display(CPI_data)
# Out:
#      year    period       date      CPI  CPI_Percent
# 239  1999   January 1999-01-01  164.300         1.70
# 238  1999  February 1999-02-01  164.500         1.60
# 237  1999     March 1999-03-01  165.000         1.70
# 236  1999     April 1999-04-01  166.200         2.30
# 235  1999       May 1999-05-01  166.200         2.10
# ..    ...       ...        ...      ...          ...
# 244  2024     April 2024-04-01  313.548         3.36
# 243  2024       May 2024-05-01  314.069         3.27
# 242  2024      June 2024-06-01  314.175         2.97
# 241  2024      July 2024-07-01  314.540         2.89
# 240  2024    August 2024-08-01  314.796         2.53
#
# [308 rows x 5 columns]

# %%
merged_data = pd.merge(merged_data, CPI_data, how = 'inner', on = ['year', 'period'])

merged_data = merged_data.drop(columns = ['CPI_y', 'date_y', 'CPI_y', 'CPI_x'])
display(merged_data)
# Out:
#      year     period  Unemployment     date_x  Fed_Percent  CPI_Percent
# 0    2018   December           3.9 2018-12-01         2.27         1.91
# 1    2018   November           3.8 2018-11-01         2.20         2.18
# 2    2018    October           3.8 2018-10-01         2.19         2.52
# 3    2018  September           3.7 2018-09-01         1.95         2.28
# 4    2018     August           3.8 2018-08-01         1.91         2.70
# ..    ...        ...           ...        ...          ...          ...
# 303  2019        May           3.6 2019-05-01         2.39         1.79
# 304  2019      April           3.7 2019-04-01         2.42         2.00
# 305  2019      March           3.8 2019-03-01         2.41         1.86
# 306  2019   February           3.8 2019-02-01         2.40         1.52
# 307  2019    January           4.0 2019-01-01         2.40         1.55
#
# [308 rows x 6 columns]

# %%
merged_data = merged_data.sort_values(by=['date_x'])

fig, ax = plt.subplots(figsize=(15,10))

#plt.plot(merged_data['date'], merged_data['CPI'])
ax.plot(merged_data['date_x'], merged_data['CPI_Percent'], label = 'CPI (Percent)')
ax.plot(merged_data['date_x'], merged_data['Fed_Percent'], label = 'FED Funds Rate (Percent)')
ax.plot(merged_data['date_x'], merged_data['Unemployment'], label = 'Unemployment Rate (Percent)')

ax.axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)
#midpoint = recession
ax.text(pd.Timestamp('2001-07-01 00:00:00'), 15, 'Recession', color='black', fontsize=12, ha='center')

ax.axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)
ax.text(pd.Timestamp('2008-12-01 00:00:00'), 15, 'The Great Recession', color='black', fontsize=12, ha='center')

ax.axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)
ax.text(pd.Timestamp('2021-12-01 00:00:00'), 15, 'COVID-19 Pandemic', color='black', fontsize=12, ha='center')

#months = mdates.MonthLocator(interval=2)
#plt.gca().xaxis.set_major_locator(months)

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())


#fig.autofmt_xdate()

plt.xlabel('Time in Years')
plt.ylabel('Percent Change')
plt.title('Changes in Consumer Price Index, Unemployment Rate, and FED Fund Rate Over Time')
plt.legend(bbox_to_anchor=(1,1), loc = 'center left')
plt.tight_layout()

plt.show()

# %%
merged_data['CPI_Scaled'] = (merged_data['CPI_Percent'] - merged_data['CPI_Percent'].min()) / (merged_data['CPI_Percent'].max() - merged_data['CPI_Percent'].min())
merged_data['Unemployment_Scaled'] = (merged_data['Unemployment'] - merged_data['Unemployment'].min()) / (merged_data['Unemployment'].max() - merged_data['Unemployment'].min())
merged_data['Fed_Percent_Scaled'] = (merged_data['Fed_Percent'] - merged_data['Fed_Percent'].min()) / (merged_data['Fed_Percent'].max() - merged_data['Fed_Percent'].min())

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,10))

#plt.plot(merged_data['date'], merged_data['CPI'])
#ax.subplot(2, 1, 1)
ax[0].set_title('Changes in CPI Rates and FED Fund Rates Over Time')
ax[0].plot(merged_data['date_x'], merged_data['CPI_Percent'], color = 'blue', label = 'CPI (Percent)')
ax[0].axhline(y = 2, color = 'black', linestyle = '--', alpha = 0.5) 
ax[0].set_ylabel('CPI Rate (Percent)')
ax[0].annotate('Target Rate', xy = (pd.Timestamp('2015-12-01 00:00:00'), 2), xytext = (pd.Timestamp('2015-05-01 00:00:00'), 3), arrowprops = dict(arrowstyle = '->'))

ax[0].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2001-07-01 00:00:00'), 9, 'Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2008-12-01 00:00:00'), 9, 'The Great Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2021-12-01 00:00:00'), 9, 'COVID-19 Pandemic', color='black', fontsize=12, ha='center')

#ax.subplot(2, 1, 2)
ax[1].plot(merged_data['date_x'], merged_data['Fed_Percent'], color = 'orange', label = 'FED Funds Rate (Percent)')
ax[1].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)
ax[1].set_xlabel('Time in Years')
ax[1].set_ylabel('FED Fund Rate (Percent)')
# Out:
# Text(0, 0.5, 'FED Fund Rate (Percent)')

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,10))

#plt.plot(merged_data['date'], merged_data['CPI'])
#ax.subplot(2, 1, 1)
ax[0].plot(merged_data['date_x'], merged_data['Unemployment'], color = 'green', label = 'Unemployment Rate')
ax[0].set_ylabel('Unemployment Rate (Percent)')
ax[0].set_title('Changes in Unemployment and FED Fund Rates Over Time')
ax[0].axhline(y = 3, color = 'black', linestyle = '--', alpha = 0.5) 
ax[0].axhline(y = 5, color = 'black', linestyle = '--', alpha = 0.5) 

ax[0].annotate('Target Band', xy = (pd.Timestamp('2004-12-01 00:00:00'), 5), xytext = (pd.Timestamp('2004-12-01 00:00:00'), 4), arrowprops = dict(arrowstyle = '->'));
ax[0].annotate('Target Band', xy = (pd.Timestamp('2004-12-01 00:00:00'), 3), xytext = (pd.Timestamp('2004-12-01 00:00:00'), 4), arrowprops = dict(arrowstyle = '->'));

ax[0].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2001-07-01 00:00:00'), 14, 'Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2008-12-01 00:00:00'), 14, 'The Great Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2021-12-01 00:00:00'), 14, 'COVID-19 Pandemic', color='black', fontsize=12, ha='center')

#ax.subplot(2, 1, 2)
ax[1].plot(merged_data['date_x'], merged_data['Fed_Percent'], color = 'orange', label = 'FED Funds Rate (Percent)')

ax[1].set_ylabel('Fed Funds Rate (Percent)')

ax[1].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)

ax[1].set_xlabel('Time in Years')

plt.tight_layout()

# %%
merged_data['Misery'] = merged_data['CPI_Percent'] + merged_data['Unemployment']

display(merged_data)
# Out:
#      year    period  Unemployment     date_x  Fed_Percent  CPI_Percent  \
# 239  1999   January           4.3 1999-01-01         4.63         1.70
# 238  1999  February           4.4 1999-02-01         4.76         1.60
# 237  1999     March           4.2 1999-03-01         4.81         1.70
# 236  1999     April           4.3 1999-04-01         4.74         2.30
# 235  1999       May           4.2 1999-05-01         4.74         2.10
# ..    ...       ...           ...        ...          ...          ...
# 244  2024     April           3.9 2024-04-01         5.33         3.36
# 243  2024       May           4.0 2024-05-01         5.33         3.27
# 242  2024      June           4.1 2024-06-01         5.33         2.97
# 241  2024      July           4.3 2024-07-01         5.33         2.89
# 240  2024    August           4.2 2024-08-01         5.33         2.53
#
#      CPI_Scaled  Unemployment_Scaled  Fed_Percent_Scaled  Misery
# ...

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,10))

#plt.plot(merged_data['date'], merged_data['CPI'])
#ax.subplot(2, 1, 1)
ax[0].plot(merged_data['date_x'], merged_data['Misery'], color = 'red', label = 'Misery Index')
ax[0].set_ylabel('Misery Index')
ax[0].set_title('Changes in Combined CPI and Unemployment Rate (Misery Index) Over Time')

ax[0].axhline(y = 5, color = 'black', linestyle = '--', alpha = 0.5) 
ax[0].axhline(y = 6, color = 'black', linestyle = '--', alpha = 0.5) 

ax[0].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2001-07-01 00:00:00'), 14, 'Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2008-12-01 00:00:00'), 14, 'The Great Recession', color='black', fontsize=12, ha='center')

ax[0].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)
ax[0].text(pd.Timestamp('2021-12-01 00:00:00'), 14, 'COVID-19 Pandemic', color='black', fontsize=12, ha='center')

ax[0].annotate('Target Band', xy = (pd.Timestamp('2012-01-01 00:00:00'), 6), xytext = (pd.Timestamp('2012-01-01 00:00:00'), 5.4), arrowprops = dict(arrowstyle = '->'));
ax[0].annotate('Target Band', xy = (pd.Timestamp('2012-01-01 00:00:00'), 5), xytext = (pd.Timestamp('2012-01-01 00:00:00'), 5.4), arrowprops = dict(arrowstyle = '->'));

#ax.subplot(2, 1, 2)
ax[1].plot(merged_data['date_x'], merged_data['Fed_Percent'], color = 'orange', label = 'FED Funds Rate (Percent)')

ax[1].set_ylabel('Fed Funds Rate (Percent)')

ax[1].axvspan('2001-03-01 00:00:00', '2001-11-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2007-12-01 00:00:00', '2009-06-01 00:00:00', color = 'red', alpha = .2)

ax[1].axvspan('2020-01-01 00:00:00', '2023-05-01 00:00:00', color = 'red', alpha = .2)

ax[1].set_xlabel('Time in Years')

plt.tight_layout()
